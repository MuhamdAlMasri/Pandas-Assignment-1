# %% [markdown]
# # Pandas Assignment #1

# %%
import pandas as pd

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns',1):
    display(df)
# Out:
#                id  ...
# 0      7129300520  ...
# 1      6414100192  ...
# ...           ...  ...
# 21611   291310100  ...
# 21612  1523300157  ...
#
# [21613 rows x 21 columns]

# %% [markdown]
# # Exercise 1
# ### Transforming Into Dataframe

# %%
df['bedrooms'].value_counts().rename_axis('unique_values_bedrooms').reset_index(name='counts')
# Out:
#     unique_values_bedrooms  counts
# 0                        3    9824
# 1                        4    6882
# 2                        2    2760
# 3                        5    1601
# 4                        6     272
# 5                        1     199
# 6                        7      38
# 7                        0      13
# 8                        8      13
# 9                        9       6
# 10                      10       3
# 11                      11       1
# 12                      33       1

# %% [markdown]
# # Exercise 2
# ## Part 1

# %% [markdown]
# We will start with exploring the dataset briefly and use the head function which allows to see the first 5 rows in the dataframe along with the columns.
# But hence the head function doesn't show case the whole columns we will use the option_context function.

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    display(df)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# 1             2570      7242     2.0           0     0          3      7
# ...            ...       ...     ...         ...   ...        ...    ...
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %% [markdown]
# ### The data consists of 21 columns:
# - Id: a unique number representing each property
# - Date: based on the information we have it's not the the year_bilt, it could be representing the date sold or bought by a person
# - bedrooms: representing the number of bedrooms this proprty contains
# - bathrooms: represents the number of bathrooms
# - sqft_living: represnting the size of the house inside
# - sqft_lot: resembles the size of the house including the yard up to the boundaries of the porperty.
# - Floors: represents the number of follors this proprety contains.
# - Waterfront: representing if the poperty is on the waterfront or not.
# - View: representing if the proprety has view.
# - Condition: after investigation the max number of any property is 5, meaning it's the max a proprety can get related to the condition of it.
# - Grade: representing the grade of the property.
# - Sqft_above: representing the height of th eproprety from the ground.
# - Sqft_basement: representing the size of the basement if exists.
# - Yr_built: represents the date the property has been established in.
# - Yr_renovated: represents the renovation date if applied.
# - zipcode: the zipcode of the property
# - Lat: representing the latitude.
# - long: representing longitude.

# %% [markdown]
# ### It is of our interest to know the factors affecting the price of each proprety

# %%
with pd.option_context('display.max_rows', 0, 'display.max_columns', None):
    display(df[["bedrooms","price"]].value_counts())
# Out:
# bedrooms  price
# 3         450000.0    97
#           350000.0    93
#           550000.0    86
#           500000.0    77
#           375000.0    74
#           400000.0    73
#           300000.0    73
#           250000.0    73
#           425000.0    72
#           325000.0    68
#           280000.0    65
#           475000.0    65
#                       ..
#           563500.0     1
#           563250.0     1
#           563225.0     1
#           562100.0     1
#           555565.0     1
#           561500.0     1
#           560200.0     1
#           559900.0     1
#           559500.0     1
#           555750.0     1
#           555700.0     1
# 33        640000.0     1
# Name: count, Length: 6391, dtype: int64

# %% [markdown]
# #### Taking the top 10 propreties in order to try and analyze the factors and see if there is a specific pattern that is affecting the price.

# %% [markdown]
# #

# %%
with pd.option_context('display.max_rows', 0, 'display.max_columns', None):
    display(df.nlargest(10, 'price'))
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7060000.0         5       4.50
# 9254  9208900037  20140919T000000  6890000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110000.0         5       5.25
# 8092  1924059029  20140617T000000  4670000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4490000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 7252        12050     27600     2.5           0     3          4     13
# 3914        10040     37325     2.0           1     2          3     11
# ...

# %% [markdown]
# ##### Starting with the bedrooms, we can see that all the properties ahs a minimum of 4 up to 6 bedrooms.
# ##### Bathrooms sizes are minimum of 3 up to 8.
# ##### sqft_living ranging between and is almost decending showing a great impact of the size of the property to the price.
# ##### Almost all the floors of the top 10 propreties has 2+ floors, also showing the impact on the price.
# ##### The view playing an important factor as well.
# ##### The condition of the propreties are all above average, meaning 3+.
# ##### All of the properties having 11+ grade.
# ##### Almost all of them having basments.
# ##### The most close variable to all the top 10 properties are the lat and long showing how much they impact the price.

# %% [markdown]
# ### *Taking the bottom 10 propreties in order to try and analyze the factors and see if there is a specific pattern that is affecting the price.*

# %%
with pd.option_context('display.max_rows', 0, 'display.max_columns', None):
    display(df.nsmallest(10, 'price'))
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
# 2141   1623049041  20140508T000000  82500.0         2       1.00          520
# 18468  7999600180  20140529T000000  83000.0         2       1.00          900
# 3767   1523049188  20150430T000000  84000.0         2       1.00          700
# 10253  2422049104  20140915T000000  85000.0         2       1.00          830
# 16714  1322049150  20150305T000000  85000.0         2       1.00          910
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %% [markdown]
# ## Part2

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# This shows the to5 5 rows we have in our data frame

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %% [markdown]
# This shows us the bottom 5, by defualt it is 5 but we can manage to change it by specifying the parameter

# %%
with pd.option_context('display.max_rows', 2, 'display.max_columns', 2):
    display(df)
# Out:
#                id  ... sqft_lot15
# 0      7129300520  ...       5650
# ...           ...  ...        ...
# 21612  1523300157  ...       1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# The option_context gives us the advantage of choosing how many rows and columns to display.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# It gives us the advantage in order to know the columns we have in a dataset

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# Provides us with the number of rows and columns

# %%
df.nsmallest(100,"bathrooms",keep="last")
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 19452  3980300371  20140926T000000  142000.0         0        0.0
# 14423  9543000205  20150413T000000  139950.0         0        0.0
# 10481   203100435  20140918T000000  484000.0         1        0.0
# 9854   7849202190  20141223T000000  235000.0         0        0.0
# 9773   3374500520  20150429T000000  355000.0         0        0.0
# ...           ...              ...       ...       ...        ...
# 21043  9276200220  20140717T000000  375000.0         1        1.0
# 21038   567000382  20141110T000000  370000.0         2        1.0
# 20962  1278000210  20150311T000000  110000.0         2        1.0
# 20853  1523300140  20140904T000000  325000.0         1        1.0
# 20780  6300000226  20150504T000000  380000.0         4        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19452          290     20875     1.0           0     0  ...      1
# ...

# %% [markdown]
# Keep is used for duplicate values.

# %% [markdown]
# ## Part3

# %%
# dictionary with list object in values
details = {
    'Name' : ['Ankit', 'Aishwarya', 'Shaurya', 'Shivangi'],
    'Age' : [23, 21, 22, 21],
    'University' : ['BHU', 'JNU', 'DU', 'BHU'],
}
  
# creating a Dataframe object 
df2 = pd.DataFrame(details)
df2
# Out:
#         Name  Age University
# 0      Ankit   23        BHU
# 1  Aishwarya   21        JNU
# 2    Shaurya   22         DU
# 3   Shivangi   21        BHU

# %% [markdown]
# The keys in the dictionary represents the columns and the values represents the rows

# %% [markdown]
# ## Part 4

# %%
df2=df2.astype(int,errors="ignore")
print(df2.dtypes)
# Out:
# Name          object
# Age            int32
# University    object
# dtype: object

# %% [markdown]
# Using astype to change the data type, with the error parameter in order to be able continue working even if the change is not possible

# %% [markdown]
# Converting all types into the best possible types

# %%
df2=df2.convert_dtypes()
print(df2.dtypes)
# Out:
# Name          string[python]
# Age                    Int32
# University    string[python]
# dtype: object
